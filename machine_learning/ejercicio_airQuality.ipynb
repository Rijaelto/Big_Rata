# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_csv("data/AirQualityUCI.csv",engine='python',sep=";",na_values="-200",skipfooter=114)

# %%
columns = raw_data.columns[:-2].tolist()

# %%
raw_data[columns]
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0       NaN     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0       NaN     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0       NaN     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0       NaN      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0       NaN     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# Hay campos que no tienen el dato adecuado, pero si elimino esas filas me quedo sin datos realmente.

# %%
raw_data[columns].dropna()
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 1226  30/04/2004  20.00.00    4,4       1449.0     501.0     19,5
# 1227  30/04/2004  21.00.00    3,1       1363.0     234.0     15,1
# 1228  30/04/2004  22.00.00      3       1371.0     212.0     14,6
# 1229  30/04/2004  23.00.00    3,1       1406.0     275.0     13,7
# 1230  01/05/2004  00.00.00    3,5       1425.0     275.0     15,2
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# Como los datos con -200 han sido reemplazados por el campo NaN, al usar describe me indicará el numero total de sucesos que tienen un valor distindo a NaN, es decir, valores que, en principio, son correctos.

# %%
data_cleaning_1 = raw_data[columns]
data_cleaning_1.shape
# Out:
# (9357, 15)

# %%
data_cleaning_1.describe()
# Out:
#        PT08.S1(CO)     NMHC(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)  \
# count  8991.000000   914.000000    8991.000000  7718.000000   8991.000000
# mean   1099.833166   218.811816     939.153376   246.896735    835.493605
# std     217.080037   204.459921     266.831429   212.979168    256.817320
# min     647.000000     7.000000     383.000000     2.000000    322.000000
# 25%     937.000000    67.000000     734.500000    98.000000    658.000000
# 50%    1063.000000   150.000000     909.000000   180.000000    806.000000
# 75%    1231.000000   297.000000    1116.000000   326.000000    969.500000
# max    2040.000000  1189.000000    2214.000000  1479.000000   2683.000000
#
#            NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)
# count  7715.000000   8991.000000  8991.000000
# mean    113.091251   1456.264598  1022.906128
# std      48.370108    346.206794   398.484288
# min       2.000000    551.000000   221.000000
# 25%      78.000000   1227.000000   731.500000
# ...

# %% [markdown]
# La segunda columna del describe, que se corresponde con:
#     - True hourly averaged overall Non Metanic HydroCarbons concentration in microg/m^3 (reference analyzer)
# Tiene solo 914 lecturas correctas, esa columna va a dar problemas, así que por ahora la voy a borrar.

# %%
data_cleaning_2 = data_cleaning_1.loc[:, data_cleaning_1.columns != 'NMHC(GT)']

# %% [markdown]
# Además algunas columnas no las ha detectado correctamente.

# %%
data_cleaning_2.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)            object
# PT08.S1(CO)      float64
# C6H6(GT)          object
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                 object
# RH                object
# AH                object
# dtype: object

# %%
data_cleaning_2['CO(GT)'] = data_cleaning_2['CO(GT)'].str.replace(',', '.').astype(float)
data_cleaning_2['C6H6(GT)'] = data_cleaning_2['C6H6(GT)'].str.replace(',', '.').astype(float)
data_cleaning_2['T'] = data_cleaning_2['T'].str.replace(',', '.').astype(float)
data_cleaning_2['RH'] = data_cleaning_2['RH'].str.replace(',', '.').astype(float)
data_cleaning_2['AH'] = data_cleaning_2['AH'].str.replace(',', '.').astype(float)
# Out:
# /home/ernesto/anaconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/ernesto/anaconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/ernesto/anaconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
data_cleaning_2 = data_cleaning_2.replace(-200.000000, np.nan)

# %%
data_cleaning_2.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)      NOx(GT)  \
# count  7674.000000  8991.000000  8991.000000    8991.000000  7718.000000
# mean      2.152750  1099.833166    10.083105     939.153376   246.896735
# std       1.453252   217.080037     7.449820     266.831429   212.979168
# min       0.100000   647.000000     0.100000     383.000000     2.000000
# 25%       1.100000   937.000000     4.400000     734.500000    98.000000
# 50%       1.800000  1063.000000     8.200000     909.000000   180.000000
# 75%       2.900000  1231.000000    14.000000    1116.000000   326.000000
# max      11.900000  2040.000000    63.700000    2214.000000  1479.000000
#
#        PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)            T  \
# count   8991.000000  7715.000000   8991.000000  8991.000000  8991.000000
# mean     835.493605   113.091251   1456.264598  1022.906128    18.317829
# std      256.817320    48.370108    346.206794   398.484288     8.832116
# ...

# %%
data_cleaning_2.shape
# Out:
# (9357, 14)

# %%
data_cleaning_2.dropna(thresh=10,axis=0,inplace=True)

# %%
data_cleaning_2.shape
# Out:
# (8991, 14)

# %%
data_cleaning_3 = data_cleaning_2.reset_index(drop=True)

# %% [markdown]
# En cualquier caso las columnas del dioxido de carbono van a ser conflictivas porque tienen más de mil outlayers cada una y si elimino las filas el conjunto se verá comprometido.

# %%
no1 = data_cleaning_3[["NOx(GT)"]]

# %%
no1.dropna()
# Out:
#       NOx(GT)
# 0       166.0
# 1       103.0
# 2       131.0
# 3       172.0
# 4       131.0
# ...       ...
# 8986    472.0
# 8987    353.0
# 8988    293.0
# 8989    235.0
# 8990    265.0
#
# [7396 rows x 1 columns]

# %% [markdown]
# Son muchos campos nulos

# %%
no1[no1['NOx(GT)'].isnull()]
# Out:
#       NOx(GT)
# 9         NaN
# 33        NaN
# 39        NaN
# 57        NaN
# 81        NaN
# ...       ...
# 8308      NaN
# 8332      NaN
# 8356      NaN
# 8380      NaN
# 8390      NaN
#
# [1595 rows x 1 columns]

# %% [markdown]
# Sacaré la media de una ventana centrada en cada uno de los valores, de manera que tratare de obtener valores para los campos vacios que sean la media de los valores de los días anteriores y siguientes.

# %%
def outlayers_media(df,column):
    rollingdf = df.rolling(5,center=True,min_periods=1).mean()
    rollingdf = rollingdf.rename(columns={column: column+"_rolling"})
    auxdf = pd.concat([df, rollingdf],axis=1)
    auxdf['aux']=df[column].mask(pd.isnull, rollingdf[column+"_rolling"])
    final = auxdf[['aux']]
    final = final.rename(columns={'aux': column})
    return final

# %% [markdown]
# La ventana no es muy grande para no coger datos muy alejados de la medida de ese día, realmente no se si esto tiene sentido para el dioxido de carbono, tendría que estudiar realmente el comportamiento del dioxido de carbono en la atmosfera y en las ciudades. Podría quizás emplearse otro acercamiento que fuera más adecuado para esto, pero para una primera aproximación puede ser útil.

# %%
while no1[no1['NOx(GT)'].isnull()].shape[0] > 0:
    no1 = outlayers_media(no1,'NOx(GT)')

# %% [markdown]
# Hago lo mismo para la columna NO2(GT) y CO(GT)

# %%
no2 = data_cleaning_3[["NO2(GT)"]]
while no2[no2['NO2(GT)'].isnull()].shape[0] > 0:
    no2 = outlayers_media(no2,'NO2(GT)')

# %%
no3 = data_cleaning_3[["CO(GT)"]]
while no3[no3['CO(GT)'].isnull()].shape[0] > 0:
    no3 = outlayers_media(no3,'CO(GT)')

# %%
data_cleaning_4 = data_cleaning_3.drop(['NOx(GT)', 'NO2(GT)','CO(GT)'], axis=1)

# %%
data_cleaning_5 = pd.concat([data_cleaning_4, no1],axis=1)
data_cleaning_5 = pd.concat([data_cleaning_5, no2],axis=1)
data_cleaning_6 = pd.concat([data_cleaning_5, no3],axis=1)

# %%
data_cleaning_6.describe()
# Out:
#        PT08.S1(CO)     C6H6(GT)  PT08.S2(NMHC)  PT08.S3(NOx)  PT08.S4(NO2)  \
# count  8991.000000  8991.000000    8991.000000   8991.000000   8991.000000
# mean   1099.833166    10.083105     939.153376    835.493605   1456.264598
# std     217.080037     7.449820     266.831429    256.817320    346.206794
# min     647.000000     0.100000     383.000000    322.000000    551.000000
# 25%     937.000000     4.400000     734.500000    658.000000   1227.000000
# 50%    1063.000000     8.200000     909.000000    806.000000   1463.000000
# 75%    1231.000000    14.000000    1116.000000    969.500000   1674.000000
# max    2040.000000    63.700000    2214.000000   2683.000000   2775.000000
#
#        PT08.S5(O3)            T           RH           AH      NOx(GT)  \
# count  8991.000000  8991.000000  8991.000000  8991.000000  8991.000000
# mean   1022.906128    18.317829    49.234201     1.025530   238.256668
# std     398.484288     8.832116    17.316892     0.403813   201.630402
# ...

# %%
data_cleaning_6 = data_cleaning_6.drop(['Date', 'Time'], axis=1)

# %% [markdown]
# # Regresión

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
sns.set_color_codes("dark")

# %%
data = data_cleaning_6.copy()

# %%
X = data.loc[:, data.columns != 'NOx(GT)']
y = data[['NOx(GT)']]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,random_state = 3,test_size=0.2)

# %%
model = LinearRegression()
model.fit(x_train, y_train)

predit_train = model.predict(x_train)
predit_test = model.predict(x_test)

print('R2 en entrenamiento es: {}'.format(model.score(x_train, y_train)))
print('R2 en test es: {}'.format(r2_score(predit_test, y_test)))
# Out:
# R2 en entrenamiento es: 0.8593843314298374
# R2 en test es: 0.8246409221849591

# %% [markdown]
# # Forward selection

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,random_state = 3,test_size=0.2)

# %%
model = LinearRegression()
feature_order =  []
feature_error = []

features = list(X.columns)
for i in range(len(features)):   
    idx_try = [val for val in range(len(features)) if val not in feature_order]
    iter_error = []
    for i_try in idx_try:
        useRow = feature_order[:]
        useRow.append(i_try)
        
        use_train = x_train[X.columns[useRow]]
        use_test = x_test[X.columns[useRow]]
        
        model.fit(use_train, y_train)
        predit_test = model.predict(use_test)
        
#         rmsError = np.linalg.norm((y_test - predit_test), 2)/np.sqrt(len(y_test))
#         r2 = model.score(use_test, y_test)
#         r22 = r2_score(y_test, predit_test)
#         mae = mean_absolute_error(y_test, predit_test)
        mse = mean_squared_error(y_test, predit_test,squared=True)     
        iter_error.append(mse)        
    pos_best = np.argmin(iter_error)
    feature_order.append(idx_try[pos_best])
    feature_error.append(iter_error[pos_best])
for i in range(len(features)):
    print("Se inserta la varible {} con resulado {}".format(features[feature_order[i]],feature_error[i]))
# Out:
# Se inserta la varible CO(GT) con resulado 16023.771178855817
# Se inserta la varible NO2(GT) con resulado 11601.630958396894
# Se inserta la varible RH con resulado 9464.347440087158
# Se inserta la varible PT08.S4(NO2) con resulado 8948.76795726881
# Se inserta la varible PT08.S2(NMHC) con resulado 7125.544146802237
# Se inserta la varible AH con resulado 6259.300954212548
# Se inserta la varible C6H6(GT) con resulado 5988.500841729349
# Se inserta la varible PT08.S3(NOx) con resulado 5916.242116356358
# Se inserta la varible T con resulado 5865.9000125784505
# Se inserta la varible PT08.S5(O3) con resulado 5833.581638290609
# Se inserta la varible PT08.S1(CO) con resulado 5789.134278169495

# %%
plt.plot(feature_error)
plt.show()

# %% [markdown]
# Parece que a partir de la sexta caracteristicas no mejora mucho, se puede jugar con esto y quitar las caracteristicas que menos aportan sin perder mucho acierto.

# %% [markdown]
# # Resultado

# %%
from sklearn.decomposition import PCA

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,random_state = 3,test_size=0.2)

# %%
PCA_for_quality = PCA(n_components=1)
PCA_for_quality.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=1, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
Quality_1_component_train = PCA_for_quality.transform(x_train)
Quality_1_component_test = PCA_for_quality.transform(x_test)
Quality_1_component_train_df = pd.DataFrame(data=Quality_1_component_train, columns = ["x"])
Quality_1_component_test_df = pd.DataFrame(data=Quality_1_component_test, columns = ["x"])

# %%
model = LinearRegression()
model.fit(x_train, y_train)

predit_train = model.predict(x_train)
predit_test = model.predict(x_test)

print('R2 en entrenamiento es: {}'.format(model.score(x_train, y_train)))
print('R2 en test es: {}'.format(r2_score(predit_test, y_test)))
# Out:
# R2 en entrenamiento es: 0.8593843314298374
# R2 en test es: 0.8246409221849591

# %%
testdf = pd.concat([Quality_1_component_test_df.x.reset_index(), y_test[['NOx(GT)']].reset_index()], axis=1)

# %%
Quality_1_component_test_list = [item for sublist in Quality_1_component_test.tolist() for item in sublist]
predit_test_list = [item for sublist in predit_test.tolist() for item in sublist]

# %%
frame = {'x':Quality_1_component_test_list,'y':predit_test_list}
df = pd.DataFrame(data=frame)
df = df.sort_values(by=['x'])
df = df.reset_index(drop=True)

# %%
plt.scatter(Quality_1_component_test, y_test, color='blue')
plt.plot(df.x, df.y, color='black')

# %% [markdown]
# En esa imagen se puede ver que el modelo está sobreajustando. Habría que continuar trabajando y creo que el problema aquí son los outlayer. Además planteo varias métricas de error y he escogido mse porque para este caso concreto parece importante que los errores grandes sean más importantes, es decir, es mejor acertar cuando la polución va a ser muy alta. En ese sentido otro paso interesante sería ajustar el error para que fuera más importante quedarse por debajo que por encima del error, es decir, ahora mismo predecir menor o mayor polución tiene el mismo coste. No se si esto tiene sentido, pero debería ser peor predecir poca polución y que luego haya mucha que predecir mucha y que luego haya poca. Además dada la complejidad de los datos habría que probar con otros modelos de regresión.
